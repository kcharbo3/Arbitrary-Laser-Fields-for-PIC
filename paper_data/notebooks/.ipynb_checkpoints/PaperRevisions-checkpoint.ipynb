# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
import numpy as np
import dataclasses

import sys
sys.path.insert(0, "../")

from fourier_prop.laser_input import (
    advanced_parameters,
    input_laser_field, 
    laser_parameters, 
    propagation_parameters,
    constants,
    utils
)

from fourier_prop.propagator import propagator
from fourier_prop.read_laser import sim_grid_parameters as grid
from fourier_prop.read_laser import read_laser
from scipy.signal import hilbert

from fourier_prop.laser_visualization import laser_visualization
cmap = np.load("../colormap.npy")
cmap = mpl.colors.ListedColormap(cmap, name='myColorMap', N=cmap.shape[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 import sys
#       8 sys.path.insert(0, "../")
# ---> 10 from fourier_prop.laser_input import (
#      11     advanced_parameters,
#      12     input_laser_field,
#      13     laser_parameters,
#      14     propagation_parameters,
#      15     constants,
#      16     utils
#      17 )
#      19 from fourier_prop.propagator import propagator
#      20 from fourier_prop.read_laser import sim_grid_parameters as grid
#
# ModuleNotFoundError: No module named 'fourier_prop'
